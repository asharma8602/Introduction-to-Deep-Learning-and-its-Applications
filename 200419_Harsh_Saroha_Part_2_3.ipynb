# %% [markdown]
# <a href="https://colab.research.google.com/github/Arsh967/Introduction-to-Deep-Learning-and-its-Applications/blob/main/200419_Harsh_Saroha_Part_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mat
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e2f08815-c9f2-4dad-83c4-eb1929d79d80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2f08815-c9f2-4dad-83c4-eb1929d79d80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving House_prediction.csv to House_prediction.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['House_prediction.csv']))

# %%
df
# Out:
#                  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           São Paulo    70      2         1               1     7      acept
# 1           São Paulo   320      4         4               0    20      acept
# 2        Porto Alegre    80      1         1               1     6      acept
# 3        Porto Alegre    51      2         1               0     2      acept
# 4           São Paulo    25      1         1               0     1  not acept
# ...               ...   ...    ...       ...             ...   ...        ...
# 10687    Porto Alegre    63      2         1               1     5  not acept
# 10688       São Paulo   285      4         4               4    17      acept
# 10689  Rio de Janeiro    70      3         3               0     8  not acept
# 10690  Rio de Janeiro   120      2         2               2     8      acept
# 10691       São Paulo    80      2         1               0     -      acept
#
# ...

# %%
df_copy = df.set_index('city')

# %%
df_grouped = df_copy.groupby('city')

# %%
df_grouped.mean()
# Out:
#                       area     rooms  bathroom  parking spaces     hoa (R$)  \
# city
# Belo Horizonte  207.411765  3.020668  2.402226        1.955485  2324.197138
# Campinas        137.561547  2.355217  1.960141        1.558030   628.922626
# Porto Alegre    103.609388  2.140821  1.725901        1.044426   491.618609
# Rio de Janeiro  105.347768  2.243837  1.756163        0.744171  1079.432378
# São Paulo       158.899439  2.558859  2.467641        1.877527  1169.627994
#
#                 rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# city
# Belo Horizonte       3664.127981         272.782194            53.675676
# Campinas             2364.290739         147.657679            32.388042
# Porto Alegre         2337.699916         124.021794            36.425817
# Rio de Janeiro       3232.904064         256.853431            42.483011
# São Paulo            4652.793783         495.701716            62.428911
#
#                  total (R$)
# city
# ...

# %%
df1 = df_grouped.mean()

# %%
import matplotlib.pyplot as plt
df1.reset_index(inplace=True)

# %%
df1
# Out:
#              city        area     rooms  bathroom  parking spaces  \
# 0  Belo Horizonte  207.411765  3.020668  2.402226        1.955485
# 1        Campinas  137.561547  2.355217  1.960141        1.558030
# 2    Porto Alegre  103.609388  2.140821  1.725901        1.044426
# 3  Rio de Janeiro  105.347768  2.243837  1.756163        0.744171
# 4       São Paulo  158.899439  2.558859  2.467641        1.877527
#
#       hoa (R$)  rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# 0  2324.197138       3664.127981         272.782194            53.675676
# 1   628.922626       2364.290739         147.657679            32.388042
# 2   491.618609       2337.699916         124.021794            36.425817
# 3  1079.432378       3232.904064         256.853431            42.483011
# 4  1169.627994       4652.793783         495.701716            62.428911
#
#     total (R$)
# 0  6315.242448
# 1  3173.276671
# 2  2989.782900
# 3  4611.684877
# 4  6380.831833

# %%
plt.plot(df1['city'], df1['area'], color = 'red')
plt.xlabel('City')
plt.ylabel('Area')
plt.title('City Vs Area')
df1.columns
# Out:
# Index(['city', 'area', 'rooms', 'bathroom', 'parking spaces', 'hoa (R$)',
#        'rent amount (R$)', 'property tax (R$)', 'fire insurance (R$)',
#        'total (R$)'],
#       dtype='object')

# %%
plt.plot(df1['city'], df1['rooms'])
plt.xlabel('City')
plt.ylabel('Rooms')
plt.title('City Vs Rooms')
# Out:
# Text(0.5, 1.0, 'City Vs Rooms')

# %%
plt.plot(df1['city'], df1['bathroom'], color = 'green')
plt.xlabel('City')
plt.ylabel('Bathroom')
plt.title('City Vs Bathroom')
# Out:
# Text(0.5, 1.0, 'City Vs Bathroom')

# %%
plt.plot(df1['city'], df1['parking spaces'], color = 'blue')
plt.xlabel('City')
plt.ylabel('Parking Space')
plt.title('City Vs Parking Space')
# Out:
# Text(0.5, 1.0, 'City Vs Parking Space')

# %%
plt.plot(df1['city'], df1['hoa (R$)'], color = 'pink')
plt.xlabel('City')
plt.ylabel('HOA')
plt.title('City Vs HOA')
# Out:
# Text(0.5, 1.0, 'City Vs HOA')

# %%
plt.plot(df1['city'], df1['rent amount (R$)'] , color = 'black')
plt.xlabel('City')
plt.ylabel('Rent Amount')
plt.title('City Vs Rent Amount')
# Out:
# Text(0.5, 1.0, 'City Vs Rent Amount')

# %%
plt.plot(df1['city'], df1['property tax (R$)'])
plt.xlabel('City')
plt.ylabel('Property Tax')
plt.title('City Vs Property Tax')
# Out:
# Text(0.5, 1.0, 'City Vs Property Tax')

# %%
plt.plot(df1['city'], df1['fire insurance (R$)'])
plt.xlabel('City')
plt.ylabel('Fire insurance')
plt.title('City Vs Fire insurance')
# Out:
# Text(0.5, 1.0, 'City Vs Fire insurance')

# %%
plt.plot(df1['city'], df1['total (R$)'])
plt.xlabel('City')
plt.ylabel('Total')
plt.title('City Vs Total')
# Out:
# Text(0.5, 1.0, 'City Vs Total')

# %%
dict1 = {'not furnished' : 0, 'furnished' : 1}
dict2 = {'not acept' : 0, 'acept' : 1}
df.replace({"furniture" : dict1}, inplace = True)
df.replace({"animal" : dict2}, inplace = True)

# %%
df
# Out:
#                  city  area  rooms  bathroom  parking spaces floor  animal  \
# 0           São Paulo    70      2         1               1     7       1
# 1           São Paulo   320      4         4               0    20       1
# 2        Porto Alegre    80      1         1               1     6       1
# 3        Porto Alegre    51      2         1               0     2       1
# 4           São Paulo    25      1         1               0     1       0
# ...               ...   ...    ...       ...             ...   ...     ...
# 10687    Porto Alegre    63      2         1               1     5       0
# 10688       São Paulo   285      4         4               4    17       1
# 10689  Rio de Janeiro    70      3         3               0     8       0
# 10690  Rio de Janeiro   120      2         2               2     8       1
# 10691       São Paulo    80      2         1               0     -       1
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
df.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.193796  0.226766        0.193983  0.039626
# rooms                0.193796  1.000000  0.733763        0.617510  0.172190
# bathroom             0.226766  0.733763  1.000000        0.697379  0.118255
# parking spaces       0.193983  0.617510  0.697379        1.000000  0.127432
# animal               0.039626  0.172190  0.118255        0.127432  1.000000
# furniture            0.008175 -0.080694  0.017938       -0.004720 -0.087972
# hoa (R$)             0.006890  0.007139  0.050271        0.009321 -0.022008
# rent amount (R$)     0.180742  0.541758  0.668504        0.578361  0.067754
# property tax (R$)    0.039059  0.075252  0.109253        0.098378 -0.003006
# fire insurance (R$)  0.188078  0.565148  0.676399        0.597348  0.079152
# total (R$)           0.051799  0.134597  0.208339        0.148684 -0.007143
#
# ...

# %%
df_sao = df[df['city'] == 'São Paulo']

# %%
df_sao
# Out:
#             city  area  rooms  bathroom  parking spaces floor  animal  \
# 0      São Paulo    70      2         1               1     7       1
# 1      São Paulo   320      4         4               0    20       1
# 4      São Paulo    25      1         1               0     1       0
# 5      São Paulo   376      3         3               7     -       1
# 7      São Paulo   213      4         4               4     4       1
# ...          ...   ...    ...       ...             ...   ...     ...
# 10683  São Paulo   280      4         4               2     5       1
# 10685  São Paulo    83      3         2               2    11       1
# 10686  São Paulo   150      3         3               2     8       0
# 10688  São Paulo   285      4         4               4    17       1
# 10691  São Paulo    80      2         1               0     -       1
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
df_sao.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.306863  0.316543        0.300795  0.073565
# rooms                0.306863  1.000000  0.759432        0.645041  0.213963
# bathroom             0.316543  0.759432  1.000000        0.703530  0.159097
# parking spaces       0.300795  0.645041  0.703530        1.000000  0.165253
# animal               0.073565  0.213963  0.159097        0.165253  1.000000
# furniture           -0.018145 -0.088931  0.005864       -0.015155 -0.066208
# hoa (R$)             0.056091  0.136343  0.163205        0.115951  0.020575
# rent amount (R$)     0.274749  0.537622  0.638924        0.573373  0.107147
# property tax (R$)    0.065289  0.071702  0.101616        0.092362 -0.005308
# fire insurance (R$)  0.287069  0.557333  0.647258        0.594385  0.117734
# total (R$)           0.200612  0.376006  0.456429        0.393843  0.060635
#
# ...

# %%
df_rio = df[df['city'] == 'Rio de Janeiro']
df_rio.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.718530  0.768172        0.567354  0.051528
# rooms                0.718530  1.000000  0.675425        0.519974  0.103937
# bathroom             0.768172  0.675425  1.000000        0.603323  0.046362
# parking spaces       0.567354  0.519974  0.603323        1.000000  0.111531
# animal               0.051528  0.103937  0.046362        0.111531  1.000000
# furniture            0.010765 -0.044278  0.027863       -0.026396 -0.165612
# hoa (R$)             0.173449  0.137632  0.170234        0.153512  0.024789
# rent amount (R$)     0.680902  0.562466  0.615716        0.468447  0.016524
# property tax (R$)    0.249693  0.180408  0.220337        0.186692  0.031122
# fire insurance (R$)  0.700999  0.576094  0.621814        0.472954  0.022056
# total (R$)           0.572468  0.465115  0.523291        0.413875  0.029085
#
# ...

# %%
df_Porto = df[df['city'] == 'Porto Alegre']
df_Porto.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.690124  0.735206        0.663963  0.064102
# rooms                0.690124  1.000000  0.705644        0.569627  0.120585
# bathroom             0.735206  0.705644  1.000000        0.641386  0.094720
# parking spaces       0.663963  0.569627  0.641386        1.000000  0.074326
# animal               0.064102  0.120585  0.094720        0.074326  1.000000
# furniture            0.074250 -0.024912  0.043032        0.086537 -0.149336
# hoa (R$)             0.095235  0.062438  0.142512        0.073804  0.017036
# rent amount (R$)     0.699550  0.546301  0.702234        0.588849  0.010464
# property tax (R$)    0.519674  0.327785  0.367649        0.333243  0.081524
# fire insurance (R$)  0.723782  0.561323  0.709735        0.598674  0.018761
# total (R$)           0.658794  0.502345  0.664397        0.541981  0.023015
#
# ...

# %%
df_belo = df[df['city'] == 'Belo Horizonte']
df_belo.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.102361  0.195066        0.128086  0.036550
# rooms                0.102361  1.000000  0.711723        0.586723  0.229576
# bathroom             0.195066  0.711723  1.000000        0.648119  0.148725
# parking spaces       0.128086  0.586723  0.648119        1.000000  0.159223
# animal               0.036550  0.229576  0.148725        0.159223  1.000000
# furniture            0.076004 -0.031612  0.074712        0.064293 -0.067715
# hoa (R$)            -0.001009 -0.060357  0.049863       -0.043088 -0.067570
# rent amount (R$)     0.119535  0.583624  0.712438        0.588444  0.101760
# property tax (R$)    0.070680  0.352692  0.434067        0.418777  0.063818
# fire insurance (R$)  0.115403  0.599062  0.706540        0.592877  0.116847
# total (R$)           0.009253 -0.009942  0.111012        0.008358 -0.058549
#
# ...

# %%
df_camp = df[df['city'] == 'Campinas']
df_camp.corr()
# Out:
#                          area     rooms  bathroom  parking spaces    animal  \
# area                 1.000000  0.199057  0.221972        0.153845  0.050156
# rooms                0.199057  1.000000  0.713008        0.581296  0.167187
# bathroom             0.221972  0.713008  1.000000        0.655529  0.108581
# parking spaces       0.153845  0.581296  0.655529        1.000000  0.157061
# animal               0.050156  0.167187  0.108581        0.157061  1.000000
# furniture           -0.028681 -0.114861 -0.009265       -0.009059 -0.090861
# hoa (R$)             0.092796  0.283608  0.420015        0.163237  0.037084
# rent amount (R$)     0.205780  0.571506  0.782451        0.647257  0.088636
# property tax (R$)    0.205716  0.542670  0.708955        0.571171  0.129844
# fire insurance (R$)  0.212410  0.576677  0.782801        0.666145  0.089849
# total (R$)           0.206130  0.576327  0.793949        0.612271  0.091152
#
# ...

# %%
# the correlation matrix gives us the the extend of linear dependence of one variable over the other corr value close to 1 suggests strong linear correlation between two variables 
# and negative corr value suggests strong disagreement between the linear dependence and value near to zero show inpedendence of two quantities
