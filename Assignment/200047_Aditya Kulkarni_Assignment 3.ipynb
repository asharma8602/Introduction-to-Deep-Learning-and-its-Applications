# %%
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
mnist = tf.keras.datasets.mnist
(xtrain, ytrain), (xtest, ytest) = mnist.load_data()

xtrain = xtrain/255.0
xtest = xtest/255.0    #normalising the data 
rnn = Sequential()


#defining the model 
#print(xtrain[0])
print(ytrain[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# 5

# %%
rnn.add(LSTM(128, input_shape = (xtrain.shape[1:]), activation = 'relu' , return_sequences =True))
rnn.add(Dropout(0.2))



rnn.add(LSTM(128, activation = 'relu'))
rnn.add(Dropout(0.2))

rnn.add(Dense(32, activation = 'relu'))
rnn.add(Dropout(0.2))

rnn.add(Dense(10, activation = 'softmax'))

#building the architecture, specifying input size and activation functions 


rnn.compile( optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

rnn.fit(xtrain, ytrain, epochs = 2, validation_data = (xtest,ytest))
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 128s 67ms/step - loss: 0.6471 - accuracy: 0.7897 - val_loss: 0.1705 - val_accuracy: 0.9506
# Epoch 2/2
# 1875/1875 [==============================] - 123s 66ms/step - loss: 0.1694 - accuracy: 0.9546 - val_loss: 0.0995 - val_accuracy: 0.9706

# %%
print(rnn.predict(xtest[0]))

# %%
ytest[0]
