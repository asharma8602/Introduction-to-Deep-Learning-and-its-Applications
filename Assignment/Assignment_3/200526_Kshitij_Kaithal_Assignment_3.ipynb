# %% [markdown]
# ##Importing the libraries

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %% [markdown]
# ###Loading the dataset and normalizing the images along with One-Hot Encoding of the target variables

# %%
#Loading the mnist dataset
(X_train,y_train),(X_test,y_test)=mnist.load_data()

#Normalization
X_test,X_train=X_test/255.0,X_train/255.0

# one hot encode target values
# we know that there are 10 classes and that classes are represented as unique integers 
# We can, therefore, use a one hot encoding for the class element of each sample, 
# transforming the integer into a 10 element binary vector with a 1 for the index of the class value, and 0 values for all other classes. 
# We can achieve this with the to_categorical() utility function.
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 11501568/11490434 [==============================] - 1s 0us/step

# %% [markdown]
# ##Printing the shapes
# It is interesting to note the difference between shapes of ```y_train``` and ```Y_train```
#
# ```y_train.shape=(60000,)``` i.e. a scalar
#
# ```Y_train.shape=(60000,10)```i.e a vector after transforming into a 10 element binary vector

# %%
print(y_train.shape)
print(Y_train.shape)
print(y_test.shape)
print(Y_test.shape)
print(X_test.shape)
print(X_train.shape)
# Out:
# (60000,)
# (60000, 10)
# (10000,)
# (10000, 10)
# (10000, 28, 28)
# (60000, 28, 28)

# %% [markdown]
# ##Visualizing the MNIST dataset

# %%
# plotting first few images
plt.figure(figsize=(10,10)) 
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
  # labels
	plt.title('Labeled as {label}'.format(label=y_train[i]))
	# plot raw pixel data
	plt.imshow(X_train[i], cmap=plt.get_cmap('gray'))
# adjusting the spacing
plt.subplots_adjust(wspace=1, hspace=0.5) 
# show the figure
plt.show()

# %% [markdown]
# ###We will be using LSTM(Long Short Term Memory) along with Keras Sequential model

# %%
model=Sequential()
model.add(LSTM(64,input_shape=(28,28))) # image rows=28 and image columns=28 i.e. 28*28 pixels and 64 is the number of units in the hidden layer on which we want to apply LSTM
model.add(Dense(10,activation="softmax")) # Since we will have an output between 0-9 and mnist is meant to be classified into 10 classes
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                23808
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 24,458
# Trainable params: 24,458
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##Compiling and training the model

# %%
#We are using categorical_crossentropy because it produces one-hot array containing the probable match for each category and here we have Y_test and Y_train as one hot encoded array
model.compile(optimizer="adam",
                loss="categorical_crossentropy",
                metrics=["acc"])
history = model.fit(X_train, Y_train, epochs=50,validation_data = (X_test, Y_test))# Using epochs=50
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 17s 5ms/step - loss: 0.4203 - acc: 0.8666 - val_loss: 0.1585 - val_acc: 0.9530
# Epoch 2/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1370 - acc: 0.9591 - val_loss: 0.1252 - val_acc: 0.9618
# Epoch 3/50
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0951 - acc: 0.9718 - val_loss: 0.0827 - val_acc: 0.9752
# Epoch 4/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0737 - acc: 0.9778 - val_loss: 0.0849 - val_acc: 0.9722
# Epoch 5/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0613 - acc: 0.9815 - val_loss: 0.0839 - val_acc: 0.9728
# Epoch 6/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0523 - acc: 0.9844 - val_loss: 0.0571 - val_acc: 0.9822
# Epoch 7/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0456 - acc: 0.9862 - val_loss: 0.0522 - val_acc: 0.9835
# Epoch 8/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0392 - acc: 0.9880 - val_loss: 0.0587 - val_acc: 0.9806
# Epoch 9/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0350 - acc: 0.9894 - val_loss: 0.0540 - val_acc: 0.9827
# Epoch 10/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0313 - acc: 0.9902 - val_loss: 0.0560 - val_acc: 0.9828
# Epoch 11/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0282 - acc: 0.9912 - val_loss: 0.0513 - val_acc: 0.9850
# Epoch 12/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0263 - acc: 0.9923 - val_loss: 0.0452 - val_acc: 0.9853
# Epoch 13/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0240 - acc: 0.9922 - val_loss: 0.0468 - val_acc: 0.9854
# Epoch 14/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0213 - acc: 0.9932 - val_loss: 0.0483 - val_acc: 0.9840
# Epoch 15/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0198 - acc: 0.9939 - val_loss: 0.0461 - val_acc: 0.9866
# Epoch 16/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0183 - acc: 0.9942 - val_loss: 0.0421 - val_acc: 0.9884
# Epoch 17/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0175 - acc: 0.9947 - val_loss: 0.0452 - val_acc: 0.9871
# Epoch 18/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0155 - acc: 0.9951 - val_loss: 0.0439 - val_acc: 0.9881
# Epoch 19/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0152 - acc: 0.9951 - val_loss: 0.0494 - val_acc: 0.9855
# Epoch 20/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0146 - acc: 0.9955 - val_loss: 0.0424 - val_acc: 0.9873
# Epoch 21/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0126 - acc: 0.9960 - val_loss: 0.0437 - val_acc: 0.9883
# Epoch 22/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0131 - acc: 0.9959 - val_loss: 0.0574 - val_acc: 0.9851
# Epoch 23/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0115 - acc: 0.9964 - val_loss: 0.0505 - val_acc: 0.9870
# Epoch 24/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0134 - acc: 0.9958 - val_loss: 0.0496 - val_acc: 0.9871
# Epoch 25/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0093 - acc: 0.9971 - val_loss: 0.0450 - val_acc: 0.9881
# Epoch 26/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0122 - acc: 0.9962 - val_loss: 0.0472 - val_acc: 0.9875
# Epoch 27/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0093 - acc: 0.9971 - val_loss: 0.0514 - val_acc: 0.9854
# Epoch 28/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0094 - acc: 0.9970 - val_loss: 0.0423 - val_acc: 0.9881
# Epoch 29/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0081 - acc: 0.9975 - val_loss: 0.0467 - val_acc: 0.9878
# Epoch 30/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0103 - acc: 0.9967 - val_loss: 0.0535 - val_acc: 0.9879
# Epoch 31/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0086 - acc: 0.9971 - val_loss: 0.0531 - val_acc: 0.9869
# Epoch 32/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0087 - acc: 0.9971 - val_loss: 0.0540 - val_acc: 0.9876
# Epoch 33/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0062 - acc: 0.9981 - val_loss: 0.0661 - val_acc: 0.9844
# Epoch 34/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0081 - acc: 0.9975 - val_loss: 0.0508 - val_acc: 0.9877
# Epoch 35/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0072 - acc: 0.9980 - val_loss: 0.0494 - val_acc: 0.9884
# Epoch 36/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0070 - acc: 0.9978 - val_loss: 0.0556 - val_acc: 0.9868
# Epoch 37/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0074 - acc: 0.9977 - val_loss: 0.0502 - val_acc: 0.9882
# Epoch 38/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0065 - acc: 0.9978 - val_loss: 0.0530 - val_acc: 0.9870
# Epoch 39/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0064 - acc: 0.9980 - val_loss: 0.0541 - val_acc: 0.9880
# Epoch 40/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0070 - acc: 0.9977 - val_loss: 0.0470 - val_acc: 0.9879
# Epoch 41/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0053 - acc: 0.9983 - val_loss: 0.0581 - val_acc: 0.9864
# Epoch 42/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0064 - acc: 0.9980 - val_loss: 0.0511 - val_acc: 0.9873
# Epoch 43/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0075 - acc: 0.9979 - val_loss: 0.0568 - val_acc: 0.9877
# Epoch 44/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0050 - acc: 0.9985 - val_loss: 0.0504 - val_acc: 0.9871
# Epoch 45/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0054 - acc: 0.9985 - val_loss: 0.0547 - val_acc: 0.9866
# Epoch 46/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0050 - acc: 0.9986 - val_loss: 0.0575 - val_acc: 0.9867
# Epoch 47/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0057 - acc: 0.9981 - val_loss: 0.0586 - val_acc: 0.9872
# Epoch 48/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0062 - acc: 0.9981 - val_loss: 0.0493 - val_acc: 0.9879
# Epoch 49/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0042 - acc: 0.9986 - val_loss: 0.0621 - val_acc: 0.9876
# Epoch 50/50
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0050 - acc: 0.9983 - val_loss: 0.0537 - val_acc: 0.9877

# %% [markdown]
# ##Determining the loss and accuracy

# %%
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Loss: {0} - Acc: {1}".format(test_loss, test_acc))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0537 - acc: 0.9877
# Loss: 0.053716279566287994 - Acc: 0.9876999855041504

# %% [markdown]
# ##Plotting Loss

# %%
import matplotlib.pyplot as plt 

# list all data in history
print(history.history.keys())

epochs = range(0,50) #since epochs=50
loss_train = history.history['loss']
val_loss= history.history['val_loss']

#Plotting Loss against Epochs
plt.plot(epochs,loss_train)
plt.plot(epochs,val_loss)
plt.title('Training  loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train_loss', 'val_loss'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %% [markdown]
# ##Plotting Accuracy

# %%
accuracy = history.history['acc'] 

val_accuracy=history.history['val_acc']
#Plotting accuracy against Epochs
plt.title('Training accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(epochs,accuracy)
plt.plot(epochs,val_accuracy)
plt.legend(['train_accuracy', 'val_accuracy'], loc='lower right')
plt.show()

# %% [markdown]
# #Prediction Validation Results

# %%
y_pred = model.predict(X_test) # Prediction the model

fig, axis = plt.subplots(4, 4, figsize=(12, 14)) # plt.subplots returns a tuple containing a figure and axes objects
for i, ax in enumerate(axis.flat):
    ax.imshow(X_test[i], cmap='binary')
    ax.set(title = f"Real Number is {Y_test[i].argmax()}\nPredict Number is {y_pred[i].argmax()}");
