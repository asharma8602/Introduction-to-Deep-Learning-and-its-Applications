# %%
from google.colab import files 

uploaded= files.upload()
# Out:
#      <input type="file" id="files-3997d88e-99c7-47f2-b462-d1e7aab08a7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3997d88e-99c7-47f2-b462-d1e7aab08a7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SHIT.csv to SHIT.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
House = pd.read_csv('SHIT.csv')

##PART 2
rent = House.groupby("city").agg(np.mean)
rent.plot.bar(y='rent amount (R$)' )

# %%
rooms = House.groupby("city").agg(np.mean)
rooms.plot.bar(y='rooms')

# %%
area = House.groupby("city").agg(np.mean)
area.plot.bar(y='area' )

# %%
parkspace = House.groupby("city").agg(np.mean)
parkspace.plot.bar(y='parking spaces' )

# %%
hoa= House.groupby("floor").agg(np.mean)
hoa.plot.bar(y='hoa (R$)' )

# %%
rentzz= House.groupby("floor").agg(np.mean)
rentzz.plot.bar(y='fire insurance (R$)' )

# %%
taxxx= House.groupby("floor").agg(np.mean)
taxxx.plot.bar(y='property tax (R$)' )

# %%
taxxxX= House.groupby("furniture").agg(np.mean)
taxxxX.plot.bar(y='property tax (R$)' ) 

rentzzZ= House.groupby("furniture").agg(np.mean)
rentzzZ.plot.bar(y='fire insurance (R$)' ) 

hoaA= House.groupby("furniture").agg(np.mean)
hoaA.plot.bar(y='hoa (R$)' )
