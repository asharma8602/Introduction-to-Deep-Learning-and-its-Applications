# %% [markdown]
# # Assignment 1 Part 2

# %% [markdown]
# City-wise plotting of mean of features such as rent amount, rooms, area, floor, etc.
# Through this, you will be able to analyze which choice is the most possible(not the most preferable).

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
mpl.use('nbagg')
import matplotlib.pyplot as plt
plt.ioff()

# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
#load file
data = pd.read_csv("./House_prediction.csv", header=0, na_values='-')

# %%
# grouping data according to city
grouped_data = data.groupby(['city'])
means_of_grouped_data = grouped_data.mean()

# obtaining list of cities
cities = list(grouped_data.groups.keys())
num_of_cities = len(cities)

# obtaining columns of grouped data
columns = list(means_of_grouped_data.columns)

# %%
for column in columns:
    fig, ax = plt.subplots(1, 1)
    ax.set(title=f"{column.capitalize()} V/S City", ylabel=column.capitalize())
    ax.bar(range(1, num_of_cities+1), means_of_grouped_data[column], tick_label=cities, width=0.5)
    fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
