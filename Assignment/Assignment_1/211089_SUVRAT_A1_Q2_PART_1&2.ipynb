# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('House_prediction.csv')

# %%
df1=df.groupby('city').mean()
print(df1)
# Out:
#                       area     rooms  bathroom  parking spaces     hoa (R$)  \
# city
# Belo Horizonte  207.411765  3.020668  2.402226        1.955485  2324.197138
# Campinas        137.561547  2.355217  1.960141        1.558030   628.922626
# Porto Alegre    103.609388  2.140821  1.725901        1.044426   491.618609
# Rio de Janeiro  105.347768  2.243837  1.756163        0.744171  1079.432378
# São Paulo       158.899439  2.558859  2.467641        1.877527  1169.627994
#
#                 rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# city
# Belo Horizonte       3664.127981         272.782194            53.675676
# Campinas             2364.290739         147.657679            32.388042
# Porto Alegre         2337.699916         124.021794            36.425817
# Rio de Janeiro       3232.904064         256.853431            42.483011
# São Paulo            4652.793783         495.701716            62.428911
#
#                  total (R$)
# city
# ...

# %%
plt.bar(df1.index,df1.iloc[:,0])
plt.xlabel("City",size='20',color='red')
plt.ylabel("Average Area",size='20',color='red')
# Out:
# Text(0, 0.5, 'Average Area')

# %%
plt.bar(df1.index,df1.iloc[:,1])
plt.xlabel("City",size='20',color='red')
plt.ylabel("Average Rooms",size='20',color='red')
# Out:
# Text(0, 0.5, 'Average Rooms')

# %%
plt.bar(df1.index,df1.iloc[:,2])
plt.xlabel("City",size='20',color='red')
plt.ylabel("Average Bathroom",size='20',color='red')
# Out:
# Text(0, 0.5, 'Average Bathroom')

# %%
plt.bar(df1.index,df1.iloc[:,3])
plt.xlabel("City",size='20',color='red')
plt.ylabel("Parking Spaces",size='20',color='red')
# Out:
# Text(0, 0.5, 'Parking Spaces')

# %%
plt.bar(df1.index,df1.iloc[:,4])
plt.xlabel("City",size='20',color='red')
plt.ylabel("HOA",size='20',color='red')
# Out:
# Text(0, 0.5, 'HOA')

# %%
plt.bar(df1.index,df1.iloc[:,5])
plt.xlabel("City",size='20',color='red')
plt.ylabel("RENT AMOUNT",size='20',color='red')
# Out:
# Text(0, 0.5, 'RENT AMOUNT')

# %%
plt.bar(df1.index,df1.iloc[:,6])
plt.xlabel("City",size='20',color='red')
plt.ylabel("PROPERTY TAX",size='20',color='red')
# Out:
# Text(0, 0.5, 'PROPERTY TAX')

# %%
plt.bar(df1.index,df1.iloc[:,7])
plt.xlabel("City",size='20',color='red')
plt.ylabel("FIRE INSURANCE",size='20',color='red')
# Out:
# Text(0, 0.5, 'FIRE INSURANCE')

# %%
plt.bar(df1.index,df1.iloc[:,8])
plt.xlabel("City",size='20',color='red')
plt.ylabel("TOTAL",size='20',color='red')
# Out:
# Text(0, 0.5, 'TOTAL')

# %%
# 2nd part of Question 2
# ------
# -------

# %%
plt.plot(df1.iloc[:,6],df1.iloc[:,1],color='b', label='ROOMS',linestyle='--')
plt.plot(df1.iloc[:,6],np.log(df1.iloc[:,0]),color='r', label='AREA')
plt.plot(df1.iloc[:,6],df1.iloc[:,2]*2,color='g', label='BATHROOM')
plt.plot(df1.iloc[:,6],df1.iloc[:,3],color='k', label='PARKING SPACES')
plt.plot(df1.iloc[:,6],np.log(df1.iloc[:,5]),color='red', label='RENT AMOUNT',linestyle='--')
plt.plot(df1.iloc[:,6],np.log(df1.iloc[:,8]),color='b', label='TOTAL')
f = plt.figure()
f.set_figwidth(4)
f.set_figheight(100)
plt.show()

# %%
plt.plot(df1.iloc[:,4],df1.iloc[:,1],color='b', label='ROOMS',linestyle='--')
plt.plot(df1.iloc[:,4],np.log(df1.iloc[:,0])*0.5,color='r', label='AREA')
plt.plot(df1.iloc[:,4],df1.iloc[:,2]*2,color='g', label='BATHROOM')
plt.plot(df1.iloc[:,4],df1.iloc[:,3],color='k', label='PARKING SPACES')
plt.plot(df1.iloc[:,4],np.log(df1.iloc[:,5]),color='red', label='RENT AMOUNT',linestyle='--')
plt.plot(df1.iloc[:,4],np.log(df1.iloc[:,8]),color='b', label='TOTAL')
f = plt.figure()
f.set_figwidth(4)
f.set_figheight(100)
plt.show()

# %%
plt.plot(df1.iloc[:,7],pow(15,df1.iloc[:,1]),color='b', label='ROOMS',linestyle='--')
plt.plot(df1.iloc[:,7],(df1.iloc[:,0]*35),color='r', label='AREA')
plt.plot(df1.iloc[:,7],pow(25,df1.iloc[:,2]),color='g', label='BATHROOM')
plt.plot(df1.iloc[:,7],df1.iloc[:,3],color='k', label='PARKING SPACES')
plt.plot(df1.iloc[:,7],(df1.iloc[:,5]),color='red', label='RENT AMOUNT',linestyle='--')
plt.plot(df1.iloc[:,7],np.log(df1.iloc[:,8]),color='b', label='TOTAL')
f = plt.figure()
f.set_figwidth(4)
f.set_figheight(100)
plt.show()
