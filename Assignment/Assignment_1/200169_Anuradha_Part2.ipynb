# %%
import pandas as pd
import matplotlib as mp
from matplotlib import pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv("House_prediction.csv")

# %%
plt.rcParams["figure.figsize"] = [20.00, 10.00]
plt.rcParams["figure.autolayout"] = True
columns = ["City", "floor"]

plt.scatter(df1.city, df1.floor)
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20.00, 10.00]
plt.rcParams["figure.autolayout"] = True
columns = ["City", "floor"]

plt.scatter(df1.city, df1.rooms)
plt.show()

# %%
plt.rcParams["figure.figsize"] = [5.00, 1.00]
plt.rcParams["figure.autolayout"] = False
columns = ["City", "floor"]

plt.scatter(df1.city, df1.area)
plt.show()

# %%
df_prime=df1['property tax (R$)']
plt.rcParams["figure.figsize"] = [20.00, 20.00]
plt.rcParams["figure.autolayout"] = False
plt.scatter(df1['floor'],df_prime)

# %%
df_prime=df1['property tax (R$)']
plt.rcParams["figure.figsize"] = [20.00, 20.00]
plt.rcParams["figure.autolayout"] = False
plt.scatter(df1['area'],df_prime)

# %%
plt.scatter(df1['parking spaces'],df_prime)

# %%
fi=df1['fire insurance (R$)']
plt.scatter(df1['rooms'],fi)

# %%
plt.scatter(df1['bathroom'],fi)

# %%
df_prime=df1['property tax (R$)']
plt.rcParams["figure.figsize"] = [5.00, 5.00]
plt.rcParams["figure.autolayout"] = False
plt.scatter(df1['hoa (R$)'],fi)

# %%
df_prime=df1['property tax (R$)']
plt.rcParams["figure.figsize"] = [10.00, 5.00]
plt.rcParams["figure.autolayout"] = False
HAT=df1['hoa (R$)']
plt.scatter(df1['area'],HAT)

# %%
plt.scatter(df1['floor'],HAT)

# %%
plt.scatter(df1['parking spaces'],HAT)
