# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("House_prediction.csv")
data_sorted = data.groupby(["city"])[list(data.head(0))]
data_sorted = data_sorted.mean()
print(data_sorted.shape)
data_sorted
# Out:
# (5, 9)
#                       area     rooms  bathroom  parking spaces     hoa (R$)  \
# city
# Belo Horizonte  207.411765  3.020668  2.402226        1.955485  2324.197138
# Campinas        137.561547  2.355217  1.960141        1.558030   628.922626
# Porto Alegre    103.609388  2.140821  1.725901        1.044426   491.618609
# Rio de Janeiro  105.347768  2.243837  1.756163        0.744171  1079.432378
# São Paulo       158.899439  2.558859  2.467641        1.877527  1169.627994
#
#                 rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# city
# Belo Horizonte       3664.127981         272.782194            53.675676
# Campinas             2364.290739         147.657679            32.388042
# Porto Alegre         2337.699916         124.021794            36.425817
# Rio de Janeiro       3232.904064         256.853431            42.483011
# São Paulo            4652.793783         495.701716            62.428911
#
#                  total (R$)
# city
# ...

# %%
for i in range(data_sorted.shape[1]):
    plt.plot(data_sorted.index.tolist(),data_sorted.loc[:,list(data_sorted.head(0))[i]])
    plt.ylabel(list(data_sorted.head(0))[i])
    plt.show()

# %%
corr = data_sorted.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_3893d_row0_col0, #T_3893d_row1_col1, #T_3893d_row2_col2, #T_3893d_row3_col3, #T_3893d_row4_col4, #T_3893d_row5_col5, #T_3893d_row6_col6, #T_3893d_row7_col7, #T_3893d_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col1, #T_3893d_row1_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_3893d_row0_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col4 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col6, #T_3893d_row1_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_3893d_row0_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_3893d_row1_col2 {
#   background-color: #dddcdc;
# ...
