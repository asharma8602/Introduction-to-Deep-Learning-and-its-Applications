# %% [markdown]
# # Assignment 2
# In this assignment, we will go through Perceptron, Linear Classifiers, Loss Functions, Gradient Descent and Back Propagation.
#
#
# PS. this one is not from Stanford's course.
#
#
#
#
#
# ## Instructions
# * This notebook contain blocks of code, you are required to complete those blocks(where required)
# * You are required to copy this notebook ("copy to drive" above) and complete the code.(DO NOT CHANGE THE NAME OF THE FUNCTIONS)

# %% [markdown]
# # Part 1: Perceptron
# In this section, we will see how to implement a perceptron. Goal would be for you to delve into the mathematics.

# %% [markdown]
# ## Intro
# What's a perceptron? It's an algorithm modelled on biological computational model to classify things into binary classes. It's a supervides learning algorithm, meaning that you need to provide labelled data containing features and the actual classifications. A perceptron would take these features as input and spit out a binary value (0 or 1). While training the model with training data, we try to minimise the error and learn the parameters involved.

# %% [markdown]
# **How does it work?**\
# A perceptron is modelled on a biological neuron. A neuron has input dendrites and the output is carried by axons. Similarly, a perceptron takes inputs called "features". After processing, a perceptron gives output. For computation, it has a "weight" vector which is multipled with feature vector. An activation function is added to introduce some non linearities and the output is given out.\
# It can be represented as: $$  f=\sum_{i=1}^{m} w_ix_i +b$$
#
# Let's implement this simple function to give an output.

# %%
import numpy as np

class perceptron():
    def __init__(self,num_input_features=8):
        self.weights = np.random.randn(num_input_features)
        self.bias = np.random.random()

    def activation(self,x):
        '''
            Implement heavside step activation function here (google ;))
        '''
        if(x>1):
            return 1
        elif(x<0):
            return 0
        else:
            return 0.5

    def forward(self,x: np.ndarray):
        '''
            you have random initialized weights and bias
            you can access then using `self.weights` and `self.bias`
            you should use activation function before returning
        
            x : input features
            return : a binary value as the output of the perceptron 
        '''
        # YOUR CODE HERE
        return self.activation(np.dot(self.weights,x)+self.bias)
        # YOUR CODE HERE

# %%
np.random.seed(0)
perc = perceptron(8)
assert perc.forward(np.arange(8))==1

# %% [markdown]
# # Part 2: Linear Classifier
# In this section, we will see how to implement a linear Classifier.

# %% [markdown]
# ## Intro

# %% [markdown]
# **How does it work?**
#
# Linear Classifier uses the following function: $$Y = WX+b$$ Where, $W$ is a 2d array of weights with shape (#features, #classes).
#
#
# Let's implement this classifier.

# %%
import numpy as np

class LinearClassifier():
    def __init__(self,num_input_features=32,num_classes=5):
        self.weights = np.random.randn(num_input_features,num_classes)
        self.bias = np.random.rand(num_classes)

    def forward(self,x: np.ndarray):
        '''
            x: input features
            you have random initialized weights and bias
            you can access then using `self.weights` and `self.bias`
            return an output vector of num_classes size
        '''
        # YOUR CODE HERE
        return np.dot(x,self.weights)+self.bias
        # YOUR CODE HERE

# %%
np.random.seed(0)
lc = LinearClassifier()
lc.forward(np.random.rand(1,32))
# Should be close to:
# array([[ 1.30208164,  5.58136003,  0.87793013, -4.7332119 ,  4.81172123]])
# Out:
# array([[ 1.30208164,  5.58136003,  0.87793013, -4.7332119 ,  4.81172123]])

# %% [markdown]
# # Part 3: Loss Functions, Gradient descent and Backpropagation

# %% [markdown]
# ## Intro
#
# Loss Functions tells how "off" the output of our model is. Based upon the application, you can use several different loss functions. Formally, A loss function is a function $L:(z,y)\in\mathbb{R}\times Y\longmapsto L(z,y)\in\mathbb{R}$ that takes as inputs the predicted value $z$ corresponding to the real data value y and outputs how different they are We'll implement L1 loss, L2 loss, Logistic loss, hinge loss and cross entropy loss functions.

# %% [markdown]
# ### **L1 loss**
# L1 loss is the linear loss function  $L = \dfrac{1}{2}(y−z) $

# %%
import numpy as np
def L1Loss(z,y):
    '''
        y : True output.
        z : Predicted output.
        return : L
    '''
    return 0.5*abs(y-z)

# %% [markdown]
# ### **L2 loss**
# L2 loss is the quadratic loss function or the least square error function  $L = \dfrac{1}{2}(y−z)^2 $

# %%
import numpy as np
def L2Loss(z,y):
    '''
        y : True output. 
        z : Predicted output. 
        return : L
    '''
    return 0.5*(y-z)**2

# %% [markdown]
# ### **Hinge Loss**
# Hinge loss is: $ L = max( 0, 1 - yz ) $

# %%
import numpy as np
def hingeLoss(z,y):
    '''
        y : True output. 
        z : Predicted output. 
        return : L
    '''
    return max(0,1-y*z)

# %% [markdown]
# ### **Cross Entropy Loss**
# Another very famous loss function is Cross Entropy loss: $ L = −[ylog(z)+(1−y)log(1−z)] $.

# %%
import numpy as np
def CELoss(z,y):
    '''
        y : True output. 
        z : Predicted output. 
        return : L
    '''
    return -1*(y*np.log2(z)+(1-y)*np.log2(1-z))

# %% [markdown]
# ### **0-1 Loss**
# Loss Function used by perceptron is: $ \begin{cases}
#       0=z-y & z=y \\
#       1=\dfrac{z-y}{z-y} & z\neq y
#    \end{cases} $

# %%
import numpy as np
def zeroOneLoss(z,y):
    '''
        y : True output. 
        z : Predicted output. 
        return : L
    '''
    return 0 if z==y else 1

# %% [markdown]
# ## Cost Function
# The cost function $J$ is commonly used to assess the performance of a model, and is defined with the loss function $L$ as follows:
# $$\boxed{J(\theta)=\sum_{i=1}^mL(h_\theta(x^{(i)}), y^{(i)})}$$
# where $h_\theta$ is the hypothesis function i.e. the function used to predict the output.

# %%
lossFunctions = {
    "l1" : L1Loss,
    "l2" : L2Loss,
    "hinge" : hingeLoss,
    "cross-entropy" : CELoss,
    "0-1" : zeroOneLoss
}

def cost(Z : np.ndarray, Y : np.ndarray, loss : str):
    '''
        Z : a numpy array of predictions.
        Y : a numpy array of true values.
        return : A numpy array of costs calculated for each example.
    '''
    loss_func = lossFunctions[loss]
    J = None
    # YOUR CODE HERE
    J = [loss_func(Z[i],Y[i]) for i in range(Z.size)]
    # YOUR CODE HERE
    return J

# %% [markdown]
# ## Gradient Descent and Back Propagation
# Gradient Descent is an algorithm that minimizes the loss function by calculating it's gradient. By noting $\alpha\in\mathbb{R}$ the learning rate, the update rule for gradient descent is expressed with the learning rate $\alpha$ and the cost function $J$ as follows:
#
# $$\boxed{ W \longleftarrow W -\alpha\nabla J( W )}$$
# ​

# %% [markdown]
# But we need to find the partial derivative of Loss function wrt every parameter to know what is the slight change that we need to apply to our parameters. This becomes particularly hard if we have more than 1 layer in our algorithm. Here's where **Back Propagation** comes in. It's a way to find gradients wrt every parameter using the chain rule. Backpropagation is a method to update the weights in the neural network by taking into account the actual output and the desired output. The derivative with respect to weight w is computed using chain rule and is of the following form:
#
# $$\boxed{\frac{\partial L(z,y)}{\partial w}=\frac{\partial L(z,y)}{\partial a}\times\frac{\partial a}{\partial z}\times\frac{\partial z}{\partial w}}$$
# ​
#
# As a result, the weight is updated as follows:
#
# $$\boxed{w\longleftarrow w-\alpha\frac{\partial L(z,y)}{\partial w}}$$
#
# So, In a neural network, weights are updated as follows:
#
# * Step 1: Take a batch of training data.
# * Step 2: Perform forward propagation to obtain the corresponding loss.
# * Step 3: Backpropagate the loss to get the gradients.
# * Step 4: Use the gradients to update the weights of the network.
# ​

# %% [markdown]
# # **Bonus Problem**
#
# Now, Assuming that you know Back Propagation (read a bit about it, if you don't), we'll now implement an image classification model on CIFAR-10.

# %%
import tensorflow as tf
 
# Display the version
print(tf.__version__)    
# other imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.layers import GlobalMaxPooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Model

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import matplotlib.pyplot as plt
# Out:
# 2.8.2

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10
 
# Distribute it to train and test set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

# Reduce pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
 
# flatten the label values
y_train, y_test = y_train.flatten(), y_test.flatten()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %%
'''visualize data by plotting images'''
# YOUR CODE HERE
# plt.figure(figsize=(8, 8))
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 
          'dog', 'frog', 'horse', 'ship', 'truck']
W_grid = 10
L_grid = 10
fig, axes = plt.subplots(L_grid, W_grid, figsize = (17,17))
axes = axes.ravel()
n_train = len(x_train)
for i in np.arange(0, W_grid * L_grid):
    index = np.random.randint(0, n_train) 
    axes[i].imshow(x_train[index,1:])
    label_index = int(y_train[index])
    axes[i].set_title(labels[label_index], fontsize = 8)
    axes[i].axis('off')
plt.subplots_adjust(hspace=0.4)
# YOUR CODE HERE

# %%
# number of classes
K = len(set(y_train))
'''
 calculate total number of classes
 for output layer
'''
print("number of classes:", K)
''' 
 Build the model using the functional API
 input layer
'''
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = tf.keras.layers.BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
 
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
 
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
 
x = Flatten()(x)
x = Dropout(0.2)(x)
'''Hidden layer'''
# YOUR CODE HERE
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
# YOUR CODE HERE
 
"""last hidden layer i.e.. output layer"""
# YOUR CODE HERE
x = Dense(K, activation='softmax')(x)
 
model = Model(i, x)
# YOUR CODE HERE
 
'''model description'''
model.summary()
# Out:
# number of classes: 10
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 2,397,226
# Trainable params: 2,396,330
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Compile
''''
  YOUR CODE HERE
'''
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit
'''
  YOUR CODE HERE
'''
r = model.fit(
  x_train, y_train, validation_data=(x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 23s 7ms/step - loss: 1.2869 - accuracy: 0.5566 - val_loss: 1.1536 - val_accuracy: 0.5975
# Epoch 2/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8475 - accuracy: 0.7067 - val_loss: 0.9275 - val_accuracy: 0.6811
# Epoch 3/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6987 - accuracy: 0.7592 - val_loss: 1.0167 - val_accuracy: 0.6739
# Epoch 4/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5965 - accuracy: 0.7977 - val_loss: 0.6280 - val_accuracy: 0.7944
# Epoch 5/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5000 - accuracy: 0.8271 - val_loss: 0.6420 - val_accuracy: 0.7921
# Epoch 6/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4207 - accuracy: 0.8571 - val_loss: 0.5968 - val_accuracy: 0.8150
# Epoch 7/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.3618 - accuracy: 0.8746 - val_loss: 0.6114 - val_accuracy: 0.8021
# Epoch 8/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3036 - accuracy: 0.8954 - val_loss: 0.6054 - val_accuracy: 0.8162
# Epoch 9/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2641 - accuracy: 0.9082 - val_loss: 0.6690 - val_accuracy: 0.8047
# Epoch 10/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2258 - accuracy: 0.9223 - val_loss: 0.6629 - val_accuracy: 0.8168
# Epoch 11/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1961 - accuracy: 0.9328 - val_loss: 0.7177 - val_accuracy: 0.8079
# Epoch 12/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1760 - accuracy: 0.9403 - val_loss: 0.6384 - val_accuracy: 0.8262
# Epoch 13/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1606 - accuracy: 0.9459 - val_loss: 0.7071 - val_accuracy: 0.8149
# Epoch 14/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1427 - accuracy: 0.9511 - val_loss: 0.7225 - val_accuracy: 0.8290
# Epoch 15/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1355 - accuracy: 0.9547 - val_loss: 0.7090 - val_accuracy: 0.8259
# Epoch 16/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1238 - accuracy: 0.9580 - val_loss: 0.7140 - val_accuracy: 0.8279
# Epoch 17/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1177 - accuracy: 0.9611 - val_loss: 0.6780 - val_accuracy: 0.8393
# Epoch 18/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1078 - accuracy: 0.9633 - val_loss: 0.7905 - val_accuracy: 0.8323
# Epoch 19/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.1042 - accuracy: 0.9643 - val_loss: 0.7206 - val_accuracy: 0.8312
# Epoch 20/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0940 - accuracy: 0.9688 - val_loss: 0.7401 - val_accuracy: 0.8310
# Epoch 21/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0898 - accuracy: 0.9697 - val_loss: 0.7491 - val_accuracy: 0.8369
# Epoch 22/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0870 - accuracy: 0.9714 - val_loss: 0.7765 - val_accuracy: 0.8340
# Epoch 23/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0857 - accuracy: 0.9710 - val_loss: 0.8051 - val_accuracy: 0.8338
# Epoch 24/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0829 - accuracy: 0.9722 - val_loss: 0.8287 - val_accuracy: 0.8264
# Epoch 25/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0760 - accuracy: 0.9753 - val_loss: 0.8374 - val_accuracy: 0.8333
# Epoch 26/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0719 - accuracy: 0.9761 - val_loss: 0.7465 - val_accuracy: 0.8414
# Epoch 27/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0706 - accuracy: 0.9775 - val_loss: 0.7835 - val_accuracy: 0.8449
# Epoch 28/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0649 - accuracy: 0.9785 - val_loss: 0.8885 - val_accuracy: 0.8331
# Epoch 29/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0703 - accuracy: 0.9771 - val_loss: 0.7887 - val_accuracy: 0.8397
# Epoch 30/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0608 - accuracy: 0.9804 - val_loss: 0.8125 - val_accuracy: 0.8374
# Epoch 31/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0604 - accuracy: 0.9801 - val_loss: 0.8500 - val_accuracy: 0.8422
# Epoch 32/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0602 - accuracy: 0.9806 - val_loss: 0.8653 - val_accuracy: 0.8319
# Epoch 33/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0584 - accuracy: 0.9808 - val_loss: 0.7929 - val_accuracy: 0.8410
# Epoch 34/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0586 - accuracy: 0.9810 - val_loss: 0.7993 - val_accuracy: 0.8406
# Epoch 35/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0598 - accuracy: 0.9802 - val_loss: 0.7870 - val_accuracy: 0.8337
# Epoch 36/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0528 - accuracy: 0.9833 - val_loss: 0.9135 - val_accuracy: 0.8365
# Epoch 37/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0580 - accuracy: 0.9819 - val_loss: 0.7314 - val_accuracy: 0.8360
# Epoch 38/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0478 - accuracy: 0.9848 - val_loss: 0.8484 - val_accuracy: 0.8286
# Epoch 39/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0487 - accuracy: 0.9842 - val_loss: 0.8019 - val_accuracy: 0.8500
# Epoch 40/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0491 - accuracy: 0.9840 - val_loss: 0.8684 - val_accuracy: 0.8247
# Epoch 41/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0494 - accuracy: 0.9842 - val_loss: 0.9262 - val_accuracy: 0.8305
# Epoch 42/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0494 - accuracy: 0.9836 - val_loss: 0.8408 - val_accuracy: 0.8400
# Epoch 43/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0442 - accuracy: 0.9860 - val_loss: 0.9150 - val_accuracy: 0.8396
# Epoch 44/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.8983 - val_accuracy: 0.8315
# Epoch 45/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0438 - accuracy: 0.9857 - val_loss: 0.9413 - val_accuracy: 0.8381
# Epoch 46/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.0438 - accuracy: 0.9864 - val_loss: 0.8123 - val_accuracy: 0.8394
# Epoch 47/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0434 - accuracy: 0.9864 - val_loss: 0.8324 - val_accuracy: 0.8458
# Epoch 48/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0432 - accuracy: 0.9863 - val_loss: 0.8734 - val_accuracy: 0.8413
# Epoch 49/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.8425 - val_accuracy: 0.8403
# Epoch 50/50
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.0404 - accuracy: 0.9874 - val_loss: 0.8567 - val_accuracy: 0.8388

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc', color='red')
plt.plot(r.history['val_accuracy'], label='val_acc', color='green')
plt.legend()

# %%
# label mapping
 
labels = '''airplane automobile bird cat deerdog frog horseship truck'''.split()
 
# select the image from our test dataset
image_number = 0
 
# display the image
plt.imshow(x_test[image_number])
 
# load the image in an array
n = np.array(x_test[image_number])
 
# reshape it
p = n.reshape(1, 32, 32, 3)
 
# pass in the network for prediction and
# save the predicted label
predicted_label = labels[model.predict(p).argmax()]
 
# load the original label
original_label = labels[y_test[image_number]]
 
# display the result
print("Original label is {} and predicted label is {}".format(
    original_label, predicted_label))
# Out:
# Original label is cat and predicted label is cat

# %%
# save the model
model.save('model_assignment_2.h5')
