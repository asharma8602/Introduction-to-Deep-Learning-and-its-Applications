# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/user/Downloads/House_prediction.csv")

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# ...

# %%
#df['floor'].unique()
df['floor']=df['floor'].replace(to_replace='-',value=0)

# %%
df.head()
df['floor'].unique()
df['floor']=df['floor'].astype(int)

# %%
print(len(df))
print(df['floor'].dtype)
# Out:
# 10692
# int32

# %%
cities=list(df.city.unique())

# %%
print(cities)
# Out:
# ['São Paulo', 'Porto Alegre', 'Rio de Janeiro', 'Campinas', 'Belo Horizonte']

# %%
df_sao=df[df['city']==cities[0]]
df_porto=df[df['city']==cities[1]]
df_rio=df[df['city']==cities[2]]
df_campinas=df[df['city']==cities[3]]
df_belo=df[df['city']==cities[4]]

# %%
rent=[]
room=[]
area=[]
floor=[]
hoa=[]
ptax=[]
finsurance=[]

# %%
df_sao.head()
# Out:
#         city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0  São Paulo    70      2         1               1      7      acept
# 1  São Paulo   320      4         4               0     20      acept
# 4  São Paulo    25      1         1               0      1  not acept
# 5  São Paulo   376      3         3               7      0      acept
# 7  São Paulo   213      4         4               4      4      acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 4  not furnished         0               800                 25
# 5  not furnished         0              8000                834
# 7  not furnished      2254              3223               1735
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 4                   11         836
# ...

# %%
df_sao['floor'].unique()
print(df_sao['floor'].dtype)
# Out:
# int32

# %%
df_sao.describe()
rent.append(4652)
room.append(2.55)
area.append(158.89)
floor.append(3.918)
hoa.append(1169.62)
ptax.append(495.70)
finsurance.append(62.42)

# %%
df_sao.describe()
# Out:
#                area        rooms     bathroom  parking spaces        floor  \
# count   5887.000000  5887.000000  5887.000000     5887.000000  5887.000000
# mean     158.899439     2.558859     2.467641        1.877527     5.626465
# std      347.474169     1.166365     1.503060        1.687973     6.056361
# min       11.000000     1.000000     1.000000        0.000000     0.000000
# 25%       59.000000     2.000000     1.000000        1.000000     0.000000
# 50%      106.000000     3.000000     2.000000        1.000000     4.000000
# 75%      212.000000     3.000000     4.000000        3.000000     9.000000
# max    24606.000000    10.000000    10.000000       12.000000    46.000000
#
#             hoa (R$)  rent amount (R$)  property tax (R$)  \
# count    5887.000000       5887.000000        5887.000000
# mean     1169.627994       4652.793783         495.701716
# std      4076.461180       3634.612007        4153.618928
# ...

# %%
df_porto.describe()
rent.append(2337.69)
room.append(2.14)
area.append(103.69)
floor.append(3.91)
hoa.append(491.61)
ptax.append(124.02)
finsurance.append(36.425)

# %%
df_porto.describe()
# Out:
#               area        rooms     bathroom  parking spaces        floor  \
# count  1193.000000  1193.000000  1193.000000     1193.000000  1193.000000
# mean    103.609388     2.140821     1.725901        1.044426     3.918692
# std     101.522925     1.058816     1.031944        1.156629     3.876568
# min      18.000000     1.000000     1.000000        0.000000     0.000000
# 25%      48.000000     1.000000     1.000000        0.000000     1.000000
# 50%      70.000000     2.000000     1.000000        1.000000     3.000000
# 75%     109.000000     3.000000     2.000000        2.000000     5.000000
# max     981.000000     8.000000     8.000000        8.000000    23.000000
#
#            hoa (R$)  rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# count   1193.000000       1193.000000        1193.000000          1193.000000
# mean     491.618609       2337.699916         124.021794            36.425817
# ...

# %%
df_rio.describe()
# Out:
#               area        rooms     bathroom  parking spaces        floor  \
# count  1501.000000  1501.000000  1501.000000     1501.000000  1501.000000
# mean    105.347768     2.243837     1.756163        0.744171     5.250500
# std      93.485031     1.050319     0.969108        0.860140     4.029211
# min      15.000000     1.000000     1.000000        0.000000     0.000000
# 25%      53.000000     1.000000     1.000000        0.000000     2.000000
# 50%      80.000000     2.000000     2.000000        1.000000     4.000000
# 75%     120.000000     3.000000     2.000000        1.000000     8.000000
# max     950.000000    13.000000     7.000000        8.000000    25.000000
#
#            hoa (R$)  rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# count   1501.000000       1501.000000        1501.000000          1501.000000
# mean    1079.432378       3232.904064         256.853431            42.483011
# ...

# %%
df_rio.describe()
rent.append(3232)
room.append(2.243)
area.append(105.34)
floor.append(5.25)
hoa.append(1079)
ptax.append(256)
finsurance.append(42)

# %%
df_campinas.describe()
# Out:
#                area       rooms    bathroom  parking spaces       floor  \
# count    853.000000  853.000000  853.000000      853.000000  853.000000
# mean     137.561547    2.355217    1.960141        1.558030    4.280188
# std      448.843132    1.075424    1.345591        1.516876    4.670610
# min       20.000000    1.000000    1.000000        0.000000    0.000000
# 25%       55.000000    1.000000    1.000000        1.000000    1.000000
# 50%       75.000000    2.000000    1.000000        1.000000    3.000000
# 75%      137.000000    3.000000    2.000000        2.000000    7.000000
# max    12732.000000    7.000000    7.000000        8.000000   51.000000
#
#           hoa (R$)  rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# count   853.000000        853.000000         853.000000           853.000000
# mean    628.922626       2364.290739         147.657679            32.388042
# std     675.836301       2310.903378         212.288724            33.179137
# ...

# %%
df_campinas.describe()
rent.append(2364)
room.append(2.35)
area.append(137.56)
floor.append(4.28)
hoa.append(628.92)
ptax.append(147.65)
finsurance.append(32.38)

# %%
df_belo.describe()
# Out:
#                area        rooms     bathroom  parking spaces        floor  \
# count   1258.000000  1258.000000  1258.000000     1258.000000  1258.000000
# mean     207.411765     3.020668     2.402226        1.955485     3.860890
# std     1312.428950     1.277510     1.432788        1.667583     9.406182
# min       15.000000     1.000000     1.000000        0.000000     0.000000
# 25%       67.250000     2.000000     1.000000        1.000000     0.000000
# 50%      110.000000     3.000000     2.000000        2.000000     2.000000
# 75%      220.000000     4.000000     3.000000        3.000000     5.000000
# max    46335.000000    10.000000    10.000000        8.000000   301.000000
#
#            hoa (R$)  rent amount (R$)  property tax (R$)  fire insurance (R$)  \
# count  1.258000e+03       1258.000000        1258.000000          1258.000000
# mean   2.324197e+03       3664.127981         272.782194            53.675676
# ...

# %%
df_belo.describe()
rent.append(3664)
room.append(3.02)
area.append(207.411)
floor.append(3.86)
hoa.append(2324.197)
ptax.append(272.78)
finsurance.append(53.67)

# %%
print(rent)
# Out:
# [4652, 2337.69, 3232, 2364, 3664]

# %%
plt.scatter(cities,rent)
plt.xlabel('CITIES')
plt.ylabel('RENT')
plt.show()

# %%
plt.scatter(cities,room)
plt.xlabel('CITIES')
plt.ylabel('ROOM')
plt.show()

# %%
plt.scatter(cities,area)
plt.xlabel('CITIES')
plt.ylabel('AREA')
plt.show()

# %%
plt.scatter(cities,floor)
plt.xlabel('CITIES')
plt.ylabel('FLOOR')
plt.show()

# %%
print(hoa)
# Out:
# [1169.62, 491.61, 1079, 628.92, 2324.197]

# %%
plt.scatter(room,hoa)
plt.xlabel('ROOM')
plt.ylabel("HOUSE ASSOCIATION TAX")
plt.show()

# %%
plt.scatter(room,ptax)
plt.xlabel('ROOM')
plt.ylabel("PROPERTY TAX")
plt.show()

# %% [markdown]
# ## No direct correlation could be seen between the two charactersticks of number of rooms and the different taxes
